# %%
import pandas as pd
import numpy as np
import os
import pickle
from sklearn.decomposition import NMF
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel

# %%
processed_df = pd.read_pickle("data/processed_recipes.pkl")
#processed_df

# %%
tfidf_vectorizer = TfidfVectorizer()
count_vectorizer = CountVectorizer()

# %% [markdown]
# Find dish name in recipes and filter them based on user preferences

# %%
from recommendation_models import filter_recipes

# %%
filtered_df = filter_recipes (processed_df, "masala dosa", diet = "Vegetarian")
filtered_df
# Out:
# Number of found dishes before filtering : 26
# Number of dishes after filtering: 22
#                                                    name  \
# 746       Mysore Masala Dosa Made With Ragi Dosa Batter
# 1005  Mushroom Corn Masala Dosa Recipe Using Ragi Id...
# 1007  Kanchipuram Masala Dosa Recipe With Soya Dosa ...
# 1189  Schezwan Masala Dosa Recipe Using Classic Idli...
# 1231                 Cheesy Mushroom Masala Dosa Recipe
# 1314                            Ghee Masala Dosa Recipe
# 1332           Soft Masala Dosa With Red Chutney Recipe
# 2044                            Sagu Masala Dosa Recipe
# 2528   Masala Dosa Recipe With Vegetable Filling Recipe
# 2546  Kollu Masala Dosa Recipe - High Protein Horse ...
# 2568               Onion Tomato Podi Masala Dosa Recipe
# 4816                 Cheesy Mushroom Masala Dosa Recipe
# 5609      Mysore Masala Dosa Made With Ragi Dosa Batter
# 6039  Mushroom Corn Masala Dosa Recipe Using Ragi Id...
# 6041  Kanchipuram Masala Dosa Recipe With Soya Dosa ...
# 6333  Schezwan Masala Dosa Recipe Using Classic Idli...
# 6558                            Ghee Masala Dosa Recipe
# 6585           Soft Masala Dosa With Red Chutney Recipe
# 7636                            Sagu Masala Dosa Recipe
# 8368   Masala Dosa Recipe With Vegetable Filling Recipe
# 8393  Kollu Masala Dosa Recipe - High Protein Horse ...
# 8424               Onion Tomato Podi Masala Dosa Recipe
#
#                                             ingredients  \
# 746   For the Dosa Batter 1 cup Idli Rice , (a speci...
# 1005  To make the Ragi Dosa Batter 2 cups White Urad...
# 1007  For Soya Dosa Batter 2 cups Idli Rice  1 cup S...
# 1189  For Classic Dosa Batter 1 1/4 cup White Urad D...
# 1231  For ragi dosa batter 1 cup Idli Rice  2 cups R...
# 1314  Ingredients for Filling of Masala dosa 3 Potat...
# 1332  3-1/2 cup Idli Dosa Batter Oil , to shallow fr...
# 2044  For the dosa batter 3/4 cup White Urad Dal (Sp...
# 2528  2 cups Dosa rice  1/2 cup Black Urad Dal (Spli...
# 2546  1 cup Rice  1/2 cup Horse Gram Dal (Kollu/ Kul...
# 2568  2 cups Idli Dosa Batter  1 Onion , finely chop...
# 4816  Idli Rice, Ragi Seeds, Barley (seeds), White U...
# 5609  Idli Rice, Ragi Seeds, White Urad Dal (Whole),...
# 6039  White Urad Dal (Whole), Methi Seeds (Fenugreek...
# 6041  Idli Rice, Soybeans (Whole Soya dal), White Ur...
# 6333  White Urad Dal (Whole), Methi Seeds (Fenugreek...
# 6558  Potatoes (Aloo), Onions, Ginger, Green Chillie...
# 6585  Idli Dosa Batter, Oil, Chaat Masala Powder, Po...
# 7636  White Urad Dal (Split), Red matta rice, Dosa r...
# 8368  Dosa rice, Black Urad Dal (Split), Methi Seeds...
# 8393  Rice, Horse Gram Dal (Kollu/ Kulith), Methi Se...
# 8424  Idli Dosa Batter, Onion, Tomato, Idli Dosa Pod...
#
#                                             description  \
# 746   Mysore Masala Dosa Recipe is a famous breakfas...
# 1005  Mushroom Corn Masala Dosa Recipe Using Ragi Id...
# 1007  Kanchipuram Masala Dosa is a breakfast recipe ...
# 1189  'Dosa' and 'Noodles' are two very popular stre...
# 1231  Cheesy Mushroom Masala Dosa Recipe is a wholes...
# 1314  Masala Dosas are delicious breakfast dish that...
# 1332  Dosa is a staple dish in South Indian states. ...
# 2044  Masala Dosa is one of those South Indian dishe...
# 2528  A unique sort of masala dosa recipe without th...
# 2546  A famous Konkani cuisine recipe, Horse Gram do...
# 2568  Onion Tomato Podi Masala Dosa is a quick varia...
# 4816  Cheesy Mushroom Masala Dosa Recipe is a wholes...
# 5609  Mysore Masala Dosa Recipe is a famous breakfas...
# 6039  Mushroom Corn Masala Dosa Recipe Using Ragi Id...
# 6041  Kanchipuram Masala Dosa is a breakfast recipe ...
# 6333  'Dosa' and 'Noodles' are two very popular stre...
# 6558  Masala Dosas are delicious breakfast dish that...
# 6585  Dosa is a staple dish in South Indian states. ...
# 7636  Masala Dosa is one of those South Indian dishe...
# 8368  A unique sort of masala dosa recipe without th...
# 8393  A famous Konkani cuisine recipe, Horse Gram do...
# 8424  Onion Tomato Podi Masala Dosa is a quick varia...
#
#                                            instructions       cuisine  \
# 746   To begin making the Mysore Masala Dosa Recipe,...     Karnataka
# 1005  To begin making the Mushroom Corn Masala Dosa ...        Fusion
# 1007  To begin making Kanchipuram Masala Dosa, first...  South Indian
# 1189  To begin making the Schezwan Masala Dosa Recip...        Fusion
# 1231  To begin making the Cheesy Mushroom Masala Dos...  South Indian
# 1314  To begin making the Ghee Masala Dosa Recipe, w...  South Indian
# 1332  To begin making the Soft Masala Dosa With Red ...  South Indian
# 2044  *To Prepare the Dosa batterTo begin making the...     Karnataka
# 2528  To begin making the Masala Dosa with Vegetable...  South Indian
# 2546  To make Horse Gram Masala Dosa Recipe, first c...        Konkan
# 2568  To start making Onion Tomato Podi Masala, firs...  South Indian
# 4816  To begin making the Cheesy Mushroom Masala Dos...  South Indian
# 5609  To begin making the Mysore Masala Dosa Recipe,...     Karnataka
# 6039  To begin making the Mushroom Corn Masala Dosa ...        Fusion
# 6041  To begin making Kanchipuram Masala Dosa, first...  South Indian
# 6333  To begin making the Schezwan Masala Dosa Recip...        Fusion
# 6558  To begin making the\xa0Ghee Masala Dosa Recipe...  South Indian
# 6585  To begin making the Soft Masala Dosa With Red ...  South Indian
# 7636  *To Prepare the Dosa batter, To begin making t...     Karnataka
# 8368  To begin making the Masala Dosa with Vegetable...  South Indian
# 8393  To make Horse Gram Masala Dosa Recipe, first c...        Konkan
# 8424  To start making Onion Tomato Podi Masala, firs...  South Indian
#
#                       course        diet prep_time categorized_prep_time  \
# 746   South Indian Breakfast  Vegetarian      60.0               ~1 hour
# 1005  South Indian Breakfast  Vegetarian      35.0               ~45 min
# 1007  South Indian Breakfast  Vegetarian     390.0     ~6.0 hours 30 min
# 1189                   Snack  Vegetarian      70.0        ~1 hour 15 min
# 1231  South Indian Breakfast  Vegetarian     330.0     ~5.0 hours 30 min
# 1314  South Indian Breakfast  Vegetarian      55.0               ~1 hour
# 1332  South Indian Breakfast  Vegetarian      55.0               ~1 hour
# 2044  South Indian Breakfast  Vegetarian      55.0               ~1 hour
# 2528  South Indian Breakfast  Vegetarian      40.0               ~45 min
# 2546  South Indian Breakfast  Vegetarian     960.0           ~16.0 hours
# 2568  South Indian Breakfast  Vegetarian      30.0               ~30 min
# 4816  South Indian Breakfast  Vegetarian     330.0     ~5.0 hours 30 min
# 5609  South Indian Breakfast  Vegetarian      60.0               ~1 hour
# 6039  South Indian Breakfast  Vegetarian      35.0               ~45 min
# 6041  South Indian Breakfast  Vegetarian     390.0     ~6.0 hours 30 min
# 6333                   Snack  Vegetarian      70.0        ~1 hour 15 min
# 6558  South Indian Breakfast  Vegetarian      55.0               ~1 hour
# 6585  South Indian Breakfast  Vegetarian      55.0               ~1 hour
# 7636  South Indian Breakfast  Vegetarian      55.0               ~1 hour
# 8368  South Indian Breakfast  Vegetarian      40.0               ~45 min
# 8393  South Indian Breakfast  Vegetarian     960.0           ~16.0 hours
# 8424  South Indian Breakfast  Vegetarian      30.0               ~30 min
#
#                                     cleaned_ingredients  ...  \
# 746   [idli rice, special rice available indian stor...  ...
# 1005  [white urad dal whole, methi seed fenugreek se...  ...
# 1007  [idli rice, soybean whole soya dal, white urad...  ...
# 1189  [white urad dal whole, methi seed fenugreek se...  ...
# 1231  [idli rice, ragi seed, barley seed, white urad...  ...
# 1314  [potato aloo, onion, ginger, green chilli, sli...  ...
# 1332  [idli dosa batter oil, chaat masala powder, po...  ...
# 2044  [white urad dal split, red matta rice, dosa ri...  ...
# 2528  [dosa rice, black urad dal split, methi seed f...  ...
# 2546  [rice, horse gram dal kulith, methi seed fenug...  ...
# 2568  [idli dosa batter, onion, idli dosa podi milag...  ...
# 4816  [idli rice, ragi seed, barley seed, white urad...  ...
# 5609  [idli rice, ragi seed, white urad dal whole, m...  ...
# 6039  [white urad dal whole, methi seed fenugreek se...  ...
# 6041  [idli rice, soybean whole soya dal, white urad...  ...
# 6333  [white urad dal whole, methi seed fenugreek se...  ...
# 6558  [potato aloo, onion, ginger, green chilli, cur...  ...
# 6585  [idli dosa batter, oil, chaat masala powder, p...  ...
# 7636  [white urad dal split, red matta rice, dosa ri...  ...
# 8368  [dosa rice, black urad dal split, methi seed f...  ...
# 8393  [rice, horse gram dal kulith, methi seed fenug...  ...
# 8424  [idli dosa batter, onion, idli dosa podi milag...  ...
#
#                                          processed_name  \
# 746            mysore masala dosa make ragi dosa batter
# 1005  mushroom corn masala dosa use ragi idli dosa b...
# 1007           kanchipuram masala dosa soya dosa batter
# 1189  schezwan masala dosa use classic idli dosa batter
# 1231                        cheesy mushroom masala dosa
# 1314                                   ghee masala dosa
# 1332                       soft masala dosa red chutney
# 2044                                   sagu masala dosa
# 2528                      masala dosa vegetable filling
# 2546     kollu masala dosa high protein horse gram dosa
# 2568                      onion tomato podi masala dosa
# 4816                        cheesy mushroom masala dosa
# 5609           mysore masala dosa make ragi dosa batter
# 6039  mushroom corn masala dosa use ragi idli dosa b...
# 6041           kanchipuram masala dosa soya dosa batter
# 6333  schezwan masala dosa use classic idli dosa batter
# 6558                                   ghee masala dosa
# 6585                       soft masala dosa red chutney
# 7636                                   sagu masala dosa
# 8368                      masala dosa vegetable filling
# 8393     kollu masala dosa high protein horse gram dosa
# 8424                      onion tomato podi masala dosa
#
#                                  processed_instructions  \
# 746   begin make mysore masala dosa first make ragi ...
# 1005  begin make mushroom corn masala dosa use ragi ...
# 1007  begin make kanchipuram masala dosa first prepa...
# 1189  begin make schezwan masala dosa first prepare ...
# 1231  begin make cheesy mushroom masala dosa first m...
# 1314  begin make ghee masala dosa first make potato ...
# 1332  begin make soft masala dosa red chutney first ...
# 2044  prepare dosa batterto begin make sagu masala d...
# 2528  begin make masala dosa vegetable filling start...
# 2546  make horse gram masala dosa first clean wash r...
# 2568  start make onion tomato podi masala first get ...
# 4816  begin make cheesy mushroom masala dosa first m...
# 5609  begin make mysore masala dosa first make ragi ...
# 6039  begin make mushroom corn masala dosa use ragi ...
# 6041  begin make kanchipuram masala dosa first prepa...
# 6333  begin make schezwan masala dosa prepare dosa b...
# 6558  begin make masala dosa first make potato masal...
# 6585  begin make soft masala dosa red chutney first ...
# 7636  prepare dosa batter begin make sagu masala dos...
# 8368  begin make masala dosa vegetable filling start...
# 8393  make horse gram masala dosa first clean wash r...
# 8424  start make onion tomato podi masala first get ...
#
#                                   processed_description  \
# 746   mysore masala dosa famous breakfast dish among...
# 1005  mushroom corn masala dosa use ragi idli dosa b...
# 1007  kanchipuram masala dosa breakfast stuff beetro...
# 1189  dosa noodle two popular street food dish india...
# 1231  cheesy mushroom masala dosa wholesome dish bec...
# 1314  masala dosas delicious breakfast dish fill spi...
# 1332  dosa staple dish south indian state fermented ...
# 2044  masala dosa one south indian dish need introdu...
# 2528  unique sort masala dosa without filling usual ...
# 2546  famous konkani cuisine horse gram dosa also kn...
# 2568  onion tomato podi masala dosa quick variation ...
# 4816  cheesy mushroom masala dosa wholesome dish bec...
# 5609  mysore masala dosa famous breakfast dish among...
# 6039  mushroom corn masala dosa use ragi idli dosa b...
# 6041  kanchipuram masala dosa breakfast stuff beetro...
# 6333  dosa noodle two popular street food dish india...
# 6558  masala dosas delicious breakfast dish fill spi...
# 6585  dosa staple dish south indian state fermented ...
# 7636  masala dosa one south indian dish need introdu...
# 8368  unique sort masala dosa without filling usual ...
# 8393  famous konkani cuisine horse gram dosa also kn...
# 8424  onion tomato podi masala dosa quick variation ...
#
#                                    allergen_type  \
# 746                          [Legumes and Seeds]
# 1005                                     Unknown
# 1007                         [Legumes and Seeds]
# 1189                                     Unknown
# 1231                  [Dairy, Grains and Gluten]
# 1314                         [Legumes and Seeds]
# 1332                         [Legumes and Seeds]
# 2044                         [Legumes and Seeds]
# 2528                                     Unknown
# 2546                         [Legumes and Seeds]
# 2568                         [Legumes and Seeds]
# 4816                  [Dairy, Grains and Gluten]
# 5609                         [Legumes and Seeds]
# 6039  [Tree Nuts and Peanuts, Legumes and Seeds]
# 6041                         [Legumes and Seeds]
# 6333                         [Legumes and Seeds]
# 6558                         [Legumes and Seeds]
# 6585                         [Legumes and Seeds]
# 7636                         [Legumes and Seeds]
# 8368                         [Legumes and Seeds]
# 8393                         [Legumes and Seeds]
# 8424                         [Legumes and Seeds]
#
#                                   processed_ingredients  \
# 746   idli rice special rice available indian store ...
# 1005  white urad dal whole methi seed fenugreek seed...
# 1007  idli rice soybean whole soya dal white urad da...
# 1189  white urad dal whole methi seed fenugreek seed...
# 1231  idli rice ragi seed barley seed white urad dal...
# 1314  potato aloo onion ginger green chilli slit spr...
# 1332  idli dosa batter oil chaat masala powder potat...
# 2044  white urad dal split red matta rice dosa rice ...
# 2528  dosa rice black urad dal split methi seed fenu...
# 2546  rice horse gram dal kulith methi seed fenugree...
# 2568  idli dosa batter onion idli dosa podi milagai ...
# 4816  idli rice ragi seed barley seed white urad dal...
# 5609  idli rice ragi seed white urad dal whole methi...
# 6039  white urad dal whole methi seed fenugreek seed...
# 6041  idli rice soybean whole soya dal white urad da...
# 6333  white urad dal whole methi seed fenugreek seed...
# 6558  potato aloo onion ginger green chilli curry co...
# 6585  idli dosa batter oil chaat masala powder potat...
# 7636  white urad dal split red matta rice dosa rice ...
# 8368  dosa rice black urad dal split methi seed fenu...
# 8393  rice horse gram dal kulith methi seed fenugree...
# 8424  idli dosa batter onion idli dosa podi milagai ...
#
#                               combined_name_ingredients  \
# 746   mysore masala dosa make ragi dosa batter idli ...
# 1005  mushroom corn masala dosa use ragi idli dosa b...
# 1007  kanchipuram masala dosa soya dosa batter idli ...
# 1189  schezwan masala dosa use classic idli dosa bat...
# 1231  cheesy mushroom masala dosa idli rice ragi see...
# 1314  ghee masala dosa potato aloo onion ginger gree...
# 1332  soft masala dosa red chutney idli dosa batter ...
# 2044  sagu masala dosa white urad dal split red matt...
# 2528  masala dosa vegetable filling dosa rice black ...
# 2546  kollu masala dosa high protein horse gram dosa...
# 2568  onion tomato podi masala dosa idli dosa batter...
# 4816  cheesy mushroom masala dosa idli rice ragi see...
# 5609  mysore masala dosa make ragi dosa batter idli ...
# 6039  mushroom corn masala dosa use ragi idli dosa b...
# 6041  kanchipuram masala dosa soya dosa batter idli ...
# 6333  schezwan masala dosa use classic idli dosa bat...
# 6558  ghee masala dosa potato aloo onion ginger gree...
# 6585  soft masala dosa red chutney idli dosa batter ...
# 7636  sagu masala dosa white urad dal split red matt...
# 8368  masala dosa vegetable filling dosa rice black ...
# 8393  kollu masala dosa high protein horse gram dosa...
# 8424  onion tomato podi masala dosa idli dosa batter...
#
#                                          combined_texts prep_time_str  \
# 746   mysore masala dosa make ragi dosa batter idli ...          60.0
# 1005  mushroom corn masala dosa use ragi idli dosa b...          35.0
# 1007  kanchipuram masala dosa soya dosa batter idli ...         390.0
# 1189  schezwan masala dosa use classic idli dosa bat...          70.0
# 1231  cheesy mushroom masala dosa idli rice ragi see...         330.0
# 1314  ghee masala dosa potato aloo onion ginger gree...          55.0
# 1332  soft masala dosa red chutney idli dosa batter ...          55.0
# 2044  sagu masala dosa white urad dal split red matt...          55.0
# 2528  masala dosa vegetable filling dosa rice black ...          40.0
# 2546  kollu masala dosa high protein horse gram dosa...         960.0
# 2568  onion tomato podi masala dosa idli dosa batter...          30.0
# 4816  cheesy mushroom masala dosa idli rice ragi see...         330.0
# 5609  mysore masala dosa make ragi dosa batter idli ...          60.0
# 6039  mushroom corn masala dosa use ragi idli dosa b...          35.0
# 6041  kanchipuram masala dosa soya dosa batter idli ...         390.0
# 6333  schezwan masala dosa use classic idli dosa bat...          70.0
# 6558  ghee masala dosa potato aloo onion ginger gree...          55.0
# 6585  soft masala dosa red chutney idli dosa batter ...          55.0
# 7636  sagu masala dosa white urad dal split red matt...          55.0
# 8368  masala dosa vegetable filling dosa rice black ...          40.0
# 8393  kollu masala dosa high protein horse gram dosa...         960.0
# 8424  onion tomato podi masala dosa idli dosa batter...          30.0
#
#                              allergen_type_str  \
# 746                          Legumes and Seeds
# 1005
# 1007                         Legumes and Seeds
# 1189
# 1231                  Dairy, Grains and Gluten
# 1314                         Legumes and Seeds
# 1332                         Legumes and Seeds
# 2044                         Legumes and Seeds
# 2528
# 2546                         Legumes and Seeds
# 2568                         Legumes and Seeds
# 4816                  Dairy, Grains and Gluten
# 5609                         Legumes and Seeds
# 6039  Tree Nuts and Peanuts, Legumes and Seeds
# 6041                         Legumes and Seeds
# 6333                         Legumes and Seeds
# 6558                         Legumes and Seeds
# 6585                         Legumes and Seeds
# 7636                         Legumes and Seeds
# 8368                         Legumes and Seeds
# 8393                         Legumes and Seeds
# 8424                         Legumes and Seeds
#
#                                            combined_all
# 746   mysore masala dosa make ragi dosa batter idli ...
# 1005  mushroom corn masala dosa use ragi idli dosa b...
# 1007  kanchipuram masala dosa soya dosa batter idli ...
# 1189  schezwan masala dosa use classic idli dosa bat...
# 1231  cheesy mushroom masala dosa idli rice ragi see...
# 1314  ghee masala dosa potato aloo onion ginger gree...
# 1332  soft masala dosa red chutney idli dosa batter ...
# 2044  sagu masala dosa white urad dal split red matt...
# 2528  masala dosa vegetable filling dosa rice black ...
# 2546  kollu masala dosa high protein horse gram dosa...
# 2568  onion tomato podi masala dosa idli dosa batter...
# 4816  cheesy mushroom masala dosa idli rice ragi see...
# 5609  mysore masala dosa make ragi dosa batter idli ...
# 6039  mushroom corn masala dosa use ragi idli dosa b...
# 6041  kanchipuram masala dosa soya dosa batter idli ...
# 6333  schezwan masala dosa use classic idli dosa bat...
# 6558  ghee masala dosa potato aloo onion ginger gree...
# 6585  soft masala dosa red chutney idli dosa batter ...
# 7636  sagu masala dosa white urad dal split red matt...
# 8368  masala dosa vegetable filling dosa rice black ...
# 8393  kollu masala dosa high protein horse gram dosa...
# 8424  onion tomato podi masala dosa idli dosa batter...
#
# [22 rows x 21 columns]

# %% [markdown]
# Calculate the best number of topics using coherence score for the filtered dataframe

# %%
from recommendation_models import compute_coherence_scores

# %% [markdown]
# Train the recommendation model using topic models and vectorizers

# %%
from recommendation_models import get_recommendations
from recommendation_models import get_recommendations_nmf_tfidf
from recommendation_models import get_recommendations_nmf_count
from recommendation_models import get_recommendations_svd_tfidf
from recommendation_models import get_recommendations_svd_count

# %% [markdown]
# Get recipe recommendation using the best NMF model on TF-IDF vectorizer

# %%
recommended_recipes_nmf_tfidf = get_recommendations_nmf_tfidf(filtered_df) 
recommended_recipes_nmf_tfidf
# Out:
# c:\Users\rogha\anaconda3\envs\Tasty_AI\lib\site-packages\sklearn\decomposition\_nmf.py:1759: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# Best Number of Topics: 7 with Coherence Score: 0.7745671330265215
#
# Highest average similarity score among all dishes: 0.9530
#                                                    name similarity_score  \
# 6041  Kanchipuram Masala Dosa Recipe With Soya Dosa ...           99.97%
# 1314                            Ghee Masala Dosa Recipe           99.41%
# 6558                            Ghee Masala Dosa Recipe           98.36%
# 7636                            Sagu Masala Dosa Recipe           89.80%
# 2044                            Sagu Masala Dosa Recipe           88.94%
#
#                                     cleaned_ingredients       cuisine  \
# 6041  [idli rice, soybean whole soya dal, white urad...  South Indian
# 1314  [potato aloo, onion, ginger, green chilli, sli...  South Indian
# 6558  [potato aloo, onion, ginger, green chilli, cur...  South Indian
# 7636  [white urad dal split, red matta rice, dosa ri...     Karnataka
# 2044  [white urad dal split, red matta rice, dosa ri...     Karnataka
#
#                       course        diet             allergens prep_time
# 6041  South Indian Breakfast  Vegetarian  [mustard, soya, soy]     390.0
# 1314  South Indian Breakfast  Vegetarian             [mustard]      55.0
# 6558  South Indian Breakfast  Vegetarian             [mustard]      55.0
# 7636  South Indian Breakfast  Vegetarian             [mustard]      55.0
# 2044  South Indian Breakfast  Vegetarian             [mustard]      55.0

# %% [markdown]
# Get recipe recommendation using best NMF model on Count vectorizer

# %%
recommended_recipes_nmf_count = get_recommendations_nmf_count(filtered_df) 
recommended_recipes_nmf_count
# Out:
# c:\Users\rogha\anaconda3\envs\Tasty_AI\lib\site-packages\sklearn\decomposition\_nmf.py:1759: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# Best Number of Topics: 6 with Coherence Score: 0.5687350507700532
#
# Highest average similarity score among all dishes: 0.9818
#                                           name similarity_score  \
# 8424      Onion Tomato Podi Masala Dosa Recipe          100.00%
# 6585  Soft Masala Dosa With Red Chutney Recipe           99.91%
# 1332  Soft Masala Dosa With Red Chutney Recipe           99.91%
# 6558                   Ghee Masala Dosa Recipe           96.55%
# 1314                   Ghee Masala Dosa Recipe           94.54%
#
#                                     cleaned_ingredients       cuisine  \
# 8424  [idli dosa batter, onion, idli dosa podi milag...  South Indian
# 6585  [idli dosa batter, oil, chaat masala powder, p...  South Indian
# 1332  [idli dosa batter oil, chaat masala powder, po...  South Indian
# 6558  [potato aloo, onion, ginger, green chilli, cur...  South Indian
# 1314  [potato aloo, onion, ginger, green chilli, sli...  South Indian
#
#                       course        diet  allergens prep_time
# 8424  South Indian Breakfast  Vegetarian  [mustard]      30.0
# 6585  South Indian Breakfast  Vegetarian  [mustard]      55.0
# 1332  South Indian Breakfast  Vegetarian  [mustard]      55.0
# 6558  South Indian Breakfast  Vegetarian  [mustard]      55.0
# 1314  South Indian Breakfast  Vegetarian  [mustard]      55.0

# %% [markdown]
# Get recipe recommendation using best SVD model on TF-IDF vectorizer

# %%
recommended_recipes_svd_tfidf = get_recommendations_svd_tfidf(filtered_df) 
recommended_recipes_svd_tfidf
# Out:
# Best Number of Topics: 5 with Coherence Score: 0.7197442012582123
#
# Highest average similarity score among all dishes: 0.9108
#                                                    name similarity_score  \
# 5609      Mysore Masala Dosa Made With Ragi Dosa Batter           99.82%
# 8393  Kollu Masala Dosa Recipe - High Protein Horse ...           91.35%
# 2546  Kollu Masala Dosa Recipe - High Protein Horse ...           90.91%
# 8368   Masala Dosa Recipe With Vegetable Filling Recipe           86.91%
# 2528   Masala Dosa Recipe With Vegetable Filling Recipe           86.45%
#
#                                     cleaned_ingredients       cuisine  \
# 5609  [idli rice, ragi seed, white urad dal whole, m...     Karnataka
# 8393  [rice, horse gram dal kulith, methi seed fenug...        Konkan
# 2546  [rice, horse gram dal kulith, methi seed fenug...        Konkan
# 8368  [dosa rice, black urad dal split, methi seed f...  South Indian
# 2528  [dosa rice, black urad dal split, methi seed f...  South Indian
#
#                       course        diet  allergens prep_time
# 5609  South Indian Breakfast  Vegetarian  [mustard]      60.0
# 8393  South Indian Breakfast  Vegetarian  [mustard]     960.0
# 2546  South Indian Breakfast  Vegetarian  [mustard]     960.0
# 8368  South Indian Breakfast  Vegetarian  [mustard]      40.0
# 2528  South Indian Breakfast  Vegetarian    unknown      40.0

# %% [markdown]
# Get recipe recommendation using best SVD model on Count vectorizer

# %%
recommended_recipes_svd_count = get_recommendations_svd_count(filtered_df) 
recommended_recipes_svd_count
# Out:
# Best Number of Topics: 5 with Coherence Score: 0.671767269117809
#
# Highest average similarity score among all dishes: 0.9458
#                                                    name similarity_score  \
# 5609      Mysore Masala Dosa Made With Ragi Dosa Batter           99.95%
# 2546  Kollu Masala Dosa Recipe - High Protein Horse ...           97.52%
# 8393  Kollu Masala Dosa Recipe - High Protein Horse ...           97.45%
# 2528   Masala Dosa Recipe With Vegetable Filling Recipe           89.29%
# 8368   Masala Dosa Recipe With Vegetable Filling Recipe           88.70%
#
#                                     cleaned_ingredients       cuisine  \
# 5609  [idli rice, ragi seed, white urad dal whole, m...     Karnataka
# 2546  [rice, horse gram dal kulith, methi seed fenug...        Konkan
# 8393  [rice, horse gram dal kulith, methi seed fenug...        Konkan
# 2528  [dosa rice, black urad dal split, methi seed f...  South Indian
# 8368  [dosa rice, black urad dal split, methi seed f...  South Indian
#
#                       course        diet  allergens prep_time
# 5609  South Indian Breakfast  Vegetarian  [mustard]      60.0
# 2546  South Indian Breakfast  Vegetarian  [mustard]     960.0
# 8393  South Indian Breakfast  Vegetarian  [mustard]     960.0
# 2528  South Indian Breakfast  Vegetarian    unknown      40.0
# 8368  South Indian Breakfast  Vegetarian  [mustard]      40.0

# %% [markdown]
# Compare recommendation models and choose the one with the highest average of similarity score as the best model

# %%
def compare_recommendation_models(filtered_df):
    # Define a dictionary to store model functions and names
    model_functions = {"NMF_TFIDF": get_recommendations_nmf_tfidf, "NMF_Count": get_recommendations_nmf_count,
        "SVD_TFIDF": get_recommendations_svd_tfidf, "SVD_Count": get_recommendations_svd_count }

    results = []
    all_recommendations = {}

    for model_name, model_func in model_functions.items():
        # Get recommendations using the model
        recommended_recipes = model_func(filtered_df)

         # Store the recommendations for the current model
        all_recommendations[model_name] = recommended_recipes

        # Extract similarity scores and calculate the average
        similarity_scores = recommended_recipes['similarity_score'].str.rstrip('%').astype(float) / 100
        average_score = similarity_scores.mean()

        # Append the results to the list
        results.append({"Model": model_name, "Average Similarity Score": average_score})

    # Make a DataFrame for the results for better visualizacomparison
    similarity_df = pd.DataFrame(results)

    # Find the model with the highest average similarity score
    best_model = similarity_df.loc[similarity_df["Average Similarity Score"].idxmax()]
    best_model_name = best_model['Model']
    best_recommendations = all_recommendations[best_model_name]

    print("Comparison Table:")
    print(similarity_df)

    print(f"\nBest Model: {best_model['Model']} with Average Similarity Score: {best_model['Average Similarity Score']:.4f}")

    return best_recommendations

# %%
best_recommendations = compare_recommendation_models(filtered_df)
best_recommendations
# Out:
# c:\Users\rogha\anaconda3\envs\Tasty_AI\lib\site-packages\sklearn\decomposition\_nmf.py:1759: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# Best Number of Topics: 7 with Coherence Score: 0.7745671330265215
#
# Highest average similarity score among all dishes: 0.9530
# c:\Users\rogha\anaconda3\envs\Tasty_AI\lib\site-packages\sklearn\decomposition\_nmf.py:1759: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# Best Number of Topics: 6 with Coherence Score: 0.5687350507700532
#
# Highest average similarity score among all dishes: 0.9818
#
# Best Number of Topics: 5 with Coherence Score: 0.7197442012582123
#
# Highest average similarity score among all dishes: 0.9108
#
# Best Number of Topics: 5 with Coherence Score: 0.671767269117809
#
# Highest average similarity score among all dishes: 0.9458
#
# Comparison Table:
#        Model  Average Similarity Score
# 0  NMF_TFIDF                   0.95296
# 1  NMF_Count                   0.98182
# 2  SVD_TFIDF                   0.91088
# 3  SVD_Count                   0.94582
#
# Best Model: NMF_Count with Average Similarity Score: 0.9818
#                                           name similarity_score  \
# 8424      Onion Tomato Podi Masala Dosa Recipe          100.00%
# 6585  Soft Masala Dosa With Red Chutney Recipe           99.91%
# 1332  Soft Masala Dosa With Red Chutney Recipe           99.91%
# 6558                   Ghee Masala Dosa Recipe           96.55%
# 1314                   Ghee Masala Dosa Recipe           94.54%
#
#                                     cleaned_ingredients       cuisine  \
# 8424  [idli dosa batter, onion, idli dosa podi milag...  South Indian
# 6585  [idli dosa batter, oil, chaat masala powder, p...  South Indian
# 1332  [idli dosa batter oil, chaat masala powder, po...  South Indian
# 6558  [potato aloo, onion, ginger, green chilli, cur...  South Indian
# 1314  [potato aloo, onion, ginger, green chilli, sli...  South Indian
#
#                       course        diet  allergens prep_time
# 8424  South Indian Breakfast  Vegetarian  [mustard]      30.0
# 6585  South Indian Breakfast  Vegetarian  [mustard]      55.0
# 1332  South Indian Breakfast  Vegetarian  [mustard]      55.0
# 6558  South Indian Breakfast  Vegetarian  [mustard]      55.0
# 1314  South Indian Breakfast  Vegetarian  [mustard]      55.0

# %% [markdown]
# Save models and vectoriers used in recommendation system

# %%
def save_model(model, file_name, path='models'):
    # Ensure the directory exists
    os.makedirs(path, exist_ok=True)
    full_path = os.path.join(path, file_name)
    with open(full_path, 'wb') as f:
        pickle.dump(model, f)

# %%
def save_vectorizer(vectorizer, file_name, path='models'):
    # Ensure the directory exists
    os.makedirs(path, exist_ok=True)
    full_path = os.path.join(path, file_name)
    with open(full_path, 'wb') as f:
        pickle.dump(vectorizer, f)

# %%
def get_recommendations_save_pickles(filtered_df, vectorizer, model, file_name, path, num_recommendations=5): 

    best_num_topics = compute_coherence_scores(filtered_df, vectorizer, model)

    vectorizer_matrix = vectorizer.fit_transform(filtered_df['combined_name_ingredients'])

    # Ensure all values in tfidf_matrix are non-negative and finite
    vectorizer_matrix = np.nan_to_num(vectorizer_matrix.toarray(), nan=0.0, posinf=0.0, neginf=0.0)

    # Train the NMF model with the optimal number of topics    
    called_model = model(n_components=best_num_topics, random_state=42)
    called_model.fit(vectorizer_matrix)
    topic_matrix = called_model.transform(vectorizer_matrix)  # Topic distribution for each recipe


#   Save the vectorizer and model
    #save_vectorizer(vectorizer, file_name, path)
    #save_model(called_model, file_name, path)
    
    filtered_df = filtered_df.copy()

    # Add topic distributions to the filtered DataFrame
    for i in range(best_num_topics):
        filtered_df[f'topic_{i}'] = topic_matrix[:, i]

    dish_index = filtered_df.reset_index().index[0]  # Get the first match if there are multiple

    cosine_similarities = cosine_similarity(topic_matrix)
    
    # Get indices of the most similar recipes
    similar_indices = cosine_similarities[dish_index].argsort()[-num_recommendations-1:-1][::-1]

    recommended_recipes = filtered_df.iloc[similar_indices].copy()
    recommended_recipes["similarity_score"] = cosine_similarities[dish_index][similar_indices]

    # Scale and format similarity scores to percentages
    recommended_recipes['similarity_score'] = (recommended_recipes['similarity_score'] * 100).round(2).astype(str) + '%'

    return None

# %%
#tfidf_vect = get_recommendations_save_pickles(filtered_df, tfidf_vectorizer, NMF, "tfidf_vectorizer.pkl", path='models')

# %%
#count_vect = get_recommendations_save_pickles(filtered_df, count_vectorizer, NMF, "count_vectorizer.pkl", path='models')

# %%
#nmf_tfid_model = get_recommendations_save_pickles(filtered_df, tfidf_vectorizer, NMF, "nmf_tfidf_model.pkl", path='models')

# %%
#nmf_count_model = get_recommendations_save_pickles(filtered_df, count_vectorizer, NMF, "nmf_count_model.pkl", path='models')

# %%
#svd_tfidf_model = get_recommendations_save_pickles(filtered_df, tfidf_vectorizer, TruncatedSVD,"svd_tfidf_model.pkl", path='models')

# %%
#svd_count_model = get_recommendations_save_pickles(filtered_df, count_vectorizer,TruncatedSVD, "svd_count_model.pkl", path='models')

# %% [markdown]
# Load models and vectoriers used in recommendation system

# %%
def get_model(file_name, path='models'):
     
    full_path = os.path.join(path, file_name)
    if not os.path.exists(full_path):
        raise FileNotFoundError(f"The file '{file_name}' does not exist in the path '{path}'.")
    
    with open(full_path, 'rb') as f:
        return pickle.load(f)

# %%
#nmf_tfidf = get_model("nmf_tfidf_model.pkl", "models")
#nmf_tfidf

# %%
#nmf_count = get_model("nmf_count_model.pkl", "models")
#nmf_count

# %%
#svd_tfidf = get_model("svd_tfidf_model.pkl", "models")
#svd_tfidf

# %%
#svd_count = get_model("svd_count_model.pkl", "models")
#svd_count

# %%
def get_vectorizer(file_name, path='models'):
     
    full_path = os.path.join(path, file_name)
    if not os.path.exists(full_path):
        raise FileNotFoundError(f"The file '{file_name}' does not exist in the path '{path}'.")
    
    with open(full_path, 'rb') as f:
        return pickle.load(f)

# %%
#tfidf_vec = get_vectorizer("tfidf_vectorizer.pkl", "models")
#tfidf_vec

# %%
#count_vec = get_vectorizer("count_vectorizer.pkl", "models")
#count_vec

# %% [markdown]
# Evaluate recommendation models using Precision@k, Recall@k, and Coverage

# %%
from sklearn.metrics import precision_score, recall_score

def evaluate_recommendations(filtered_df, recommendations, processed_df, user_preferences, k=5):
    """
    Evaluate the recommendation model using Precision@k, Recall@k, and Coverage.

    Parameters:
    - filtered_df: DataFrame of filtered recipes matching user preferences.
    - recommendations: DataFrame of recommended recipes.
    - dataset: Full dataset of recipes.
    - user_preferences: Dictionary of user-specified preferences (e.g., {'cuisine': 'Indian'}).
    - k: Number of top recommendations to consider (default is 5).

    Returns:
    - metrics: Dictionary containing Precision@k, Recall@k, and Coverage.
    """
    # 1. Precision@k
    relevant_recipes = filtered_df  # Recipes that match all user preferences
    recommended_top_k = recommendations.head(k)  # Top-k recommendations

    # Check if the recommended recipes are in the relevant recipes
    relevant_in_top_k = recommended_top_k['name'].isin(relevant_recipes['name']).sum()
    precision_at_k = relevant_in_top_k / k

    # 2. Recall@k
    total_relevant = relevant_recipes.shape[0]
    recall_at_k = relevant_in_top_k / total_relevant if total_relevant > 0 else 0

    # 3. Coverage
    unique_recommended = recommendations['name'].nunique()
    total_items = processed_df['name'].nunique()
    coverage = unique_recommended / total_items

    metrics = {
        'Precision@k': round(precision_at_k, 4),
        'Recall@k': round(recall_at_k, 4),
        'Coverage': round(coverage, 4),
    }

    return metrics

# %%
# Example 
user_preferences = {'cuisine': 'fusion', 'course': 'snack', 'diet': 'Vegetarian'}

# Find filtered recipes based on user preferences
filtered_df = filter_recipes(processed_df, "masala dosa", **user_preferences)

# Get recommendations
vectorizer = TfidfVectorizer()
model = NMF
recommendations = get_recommendations(filtered_df, vectorizer, model, num_recommendations=10)

# Evaluate the recommendations
metrics = evaluate_recommendations(filtered_df, recommendations, processed_df, user_preferences, k=5)
print(metrics)
# Out:
# Number of found dishes before filtering : 26
# Number of dishes after filtering: 2
# Best Number of Topics: 2 with Coherence Score: 0.8608568823641594
#
# Highest average similarity score among all dishes: 0.0006
#
# {'Precision@k': 0.2, 'Recall@k': 0.5, 'Coverage': 0.0002}
